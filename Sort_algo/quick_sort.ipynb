# %% [markdown]
# # Key Concept
#
# 1. Pick one item (called the "pivot")
# 2. Put all smaller items on the LEFT
# 3. Put all bigger items on the RIGHT
# 4. Repeat for the left pile and right pile
#
# > Keep doing this until everything is sorted

# %%
def quick_sort(arr):
    """
    using multiple arrays to store data
    
    :param arr: unsorted array
    """
    # if the array has 0 return []
    # if it has 1 element it is already sorted
    if len(arr) <= 1:
        return arr 
    
    # STEP 1: pick a pivot value (picking the middle of the array)
    pivot_value = arr[len(arr)// 2]

    # STEP 2: create arrays to store the values smaller than the current , similar to or g
